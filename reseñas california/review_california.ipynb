# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/1.csv")
df2 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/2.csv")
df3 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/3.csv")
df4 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/4.csv")
df5 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/5.csv")
df6 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/6.csv")
df7 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/7.csv")
df8 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/8.csv")
df9 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/9.csv")
df10 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/10.csv")
df11 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/11.csv")
df12 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/12.csv")
df13 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/13.csv")
df14 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/14.csv")
df15 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/15.csv")
df16 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/16.csv")
df17 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/17.csv")
df18 = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/18.csv")

# %%
# Crea una lista con los DataFrames que deseas concatenar
dataframes_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18]

# Concatena los DataFrames de forma vertical
review_df = pd.concat(dataframes_list, ignore_index=True)

# %%
review_df.to_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/review-California/review-California/final/review_california.csv", index=False)

# %%
review_df
# Out:
#            user_id                            name                     time  \
# 0     1.089268e+20  Christopher Thomas Constantino  2021-06-12 23:27:17.434
# 1     1.147835e+20                     Valley Girl  2020-11-06 01:35:04.569
# 2     1.158307e+20                  John Barringer  2020-11-01 03:06:47.321
# 3     1.083060e+20                  Missey Iverson  2021-06-08 15:35:00.137
# 4     1.165939e+20                        Larry S.  2018-04-09 16:11:16.898
# ...            ...                             ...                      ...
# 3516  1.062983e+20                         Ty Dyce  2018-11-13 19:30:28.141
# 3517  1.069742e+20                  Micheal Calvin  2017-03-16 04:19:14.604
# 3518  1.179712e+20                     Sunny Singh  2016-02-13 14:49:54.115
# 3519  1.080587e+20                        Karim B.  2020-01-19 22:49:04.969
# 3520  1.086556e+20                     arthur nora  2018-02-25 18:01:46.076
#
# ...
