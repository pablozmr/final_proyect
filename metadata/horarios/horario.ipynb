# %%
import pandas as pd
import numpy as np

# %%
df1= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 1.csv")
df2= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 2.csv")
df3= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 3.csv")
df4= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 4.csv")
df5= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 5.csv")
df6= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 6.csv")
df7= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 7.csv")
df8= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 8.csv")
df9= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 9.csv")
df10= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 10.csv")
df11= pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/horarios 11.csv")

# %%
# Crea una lista con los DataFrames que deseas concatenar
dataframes_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11]

# Concatena los DataFrames de forma vertical
horario_df = pd.concat(dataframes_list, ignore_index=True)

# %%
horario_df
# Out:
#     Friday Saturday Sunday Monday Tuesday Wednesday Thursday  \
# 0      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 1      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 2      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 3      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 4      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# ..     ...      ...    ...    ...     ...       ...      ...
# 839    NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 840    NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 841    NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 842    NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 843    NaN      NaN    NaN    NaN     NaN       NaN      NaN
#
#                                    gmap_id
# 0    0x809a55833fbe05ad:0xee6507787fb6a26c
# 1    0x89dc97fd8935dd97:0x80860aef765fe4b4
# 2    0x89d486fb46b35e0f:0xf89fc350fa1c93f0
# 3    0x89dc53af65a602b5:0x10190ffe79346777
# ...

# %%
horario_df.drop_duplicates(subset='gmap_id', inplace=True, ignore_index=True)

# %%
data_merge = pd.read_csv("C:/Users/pablo/OneDrive/Escritorio/Dataset GM/metadata-sitios/metadata-sitios/metadata/metadata.csv")

# %%
# Filtra los valores únicos de la columna 'gmap_id' en el DataFrame `metadata`
gmap_ids_metadata = data_merge['gmap_id'].unique()

# Utiliza el método `isin()` para filtrar las filas en el DataFrame `df1`
# que tienen los valores de 'gmap_id' presentes en `gmap_ids_metadata`
df_horarios = horario_df[horario_df['gmap_id'].isin(gmap_ids_metadata)]

# %%
horario_df
# Out:
#     Friday Saturday Sunday Monday Tuesday Wednesday Thursday  \
# 0      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 1      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 2      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 3      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 4      NaN      NaN    NaN    NaN     NaN       NaN      NaN
# ..     ...      ...    ...    ...     ...       ...      ...
# 833    NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 834    NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 835    NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 836    NaN      NaN    NaN    NaN     NaN       NaN      NaN
# 837    NaN      NaN    NaN    NaN     NaN       NaN      NaN
#
#                                    gmap_id
# 0    0x809a55833fbe05ad:0xee6507787fb6a26c
# 1    0x89dc97fd8935dd97:0x80860aef765fe4b4
# 2    0x89d486fb46b35e0f:0xf89fc350fa1c93f0
# 3    0x89dc53af65a602b5:0x10190ffe79346777
# ...
